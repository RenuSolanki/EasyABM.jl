# %%
using Pkg, Revise
Pkg.activate(joinpath(@__DIR__, "../.."))
using EasyABM
# Out:
#   Activating project at `~/Documents/EasyABM`
# WebIO._IJuliaInit()

# %%
gr = square_grid_graph(20,10,dynamic=true);

# %%
typeof(gr)
# Out:
# EasyABM.SimplePropGraph{Mortal, EasyABM.SimG}

# %%
draw_graph(gr)

# %%
gr = hex_grid_graph(10,10);
draw_graph(gr)

# %%
gr = triangular_grid_graph(20,15);
draw_graph(gr)
